# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde s
df = pd.read_csv('Analisis GAC Full7agosto 2026(Leads Reales).csv', skiprows=2)

# %%
df.head(5)
# Out:
#       Año      Mes Total Ilocalizable No Contesta D. Incorrectos Duplicados  \
# 0  2024.0    Enero   NaN          NaN         NaN            NaN        NaN
# 1     NaN  Febrero   543          108          33              0          1
# 2     NaN    Marzo   178           37          13              0          0
# 3     NaN    Abril   416           79          46              3          0
# 4     NaN     Mayo   422           33         100             17          0
#
#   Efectivos Abiertos Ventas Conversion  Efectividad de Leads  Unnamed: 12  \
# 0       NaN      NaN    NaN         NaN                  NaN          NaN
# 1       389        1     12        3.1%                  72%          NaN
# 2       128        1      7        5.5%                  72%          NaN
# 3       288        1      8        2.8%                  69%          NaN
# 4       274        5     13        4.7%                  65%          NaN
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# ...

# %%
#Quitamos columnas y filas extra que no necesitamos
df1 = df.iloc[:29, :11]

# %%
df1.tail(5)
# Out:
#        Año      Mes  Total Ilocalizable No Contesta D. Incorrectos Duplicados  \
# 24  2026.0   Enero   1,516          148         187             52         53
# 25     NaN  Febrero  1,235          116         106              8         31
# 26     NaN   Marzo   1,785          228         184             48         32
# 27     NaN   Abril   1,393          212         123             38         28
# 28     NaN    Mayo   1,251          158         116             25         19
#
#    Efectivos Abiertos Ventas Conversion
# 24       714      602     37        5.2%
# 25       730      523     30        4.1%
# 26       944      698     38        4.0%
# 27       724      559     41        5.7%
# 28       736      458     35        4.8%

# %%
#identificamos los datos nulos
df1.isnull().sum()
# Out:
# Año               26
# Mes                0
# Total              1
# Ilocalizable       1
# No Contesta        1
# D. Incorrectos     1
# Duplicados         1
# Efectivos          1
# Abiertos           1
# Ventas             1
# Conversion         1
# dtype: int64

# %%
#Se eliminan los primeros NaN
df1[['Año', 'Mes', 'Total', 'Ilocalizable', 'No Contesta', 'D. Incorrectos',
       'Duplicados', 'Efectivos', 'Abiertos', 'Ventas', 'Conversion ']] = df1[['Año', 'Mes', 'Total', 'Ilocalizable', 'No Contesta', 'D. Incorrectos',
       'Duplicados', 'Efectivos', 'Abiertos', 'Ventas', 'Conversion ']].fillna(0) 
df1.head(5)
# Out:
#       Año      Mes Total Ilocalizable No Contesta D. Incorrectos Duplicados  \
# 0  2024.0    Enero     0            0           0              0          0
# 1     0.0  Febrero   543          108          33              0          1
# 2     0.0    Marzo   178           37          13              0          0
# 3     0.0    Abril   416           79          46              3          0
# 4     0.0     Mayo   422           33         100             17          0
#
#   Efectivos Abiertos Ventas Conversion
# 0         0        0      0           0
# 1       389        1     12        3.1%
# 2       128        1      7        5.5%
# 3       288        1      8        2.8%
# 4       274        5     13        4.7%

# %%
#Se corrigen los años 
df1.loc[1:12, 'Año'] = 2024
df1.loc[12:24, 'Año'] = 2025
df1.loc[24:, 'Año'] = 2026

# %%
#Se corrobora que se haya cambiado de manera correcta
df1
# Out:
#        Año         Mes  Total Ilocalizable No Contesta D. Incorrectos  \
# 0   2024.0       Enero      0            0           0              0
# 1   2024.0     Febrero    543          108          33              0
# 2   2024.0       Marzo    178           37          13              0
# 3   2024.0       Abril    416           79          46              3
# 4   2024.0        Mayo    422           33         100             17
# 5   2024.0       Junio    967          140         173             31
# 6   2024.0       Julio    954          112         251             12
# 7   2024.0      Agosto  1,409          504         324             17
# 8   2024.0  Septiembre  1,315          431         314             14
# 9   2024.0     Octubre  1,973          514         606             18
# 10  2024.0   Noviembre  1,562          153         321             44
# 11  2024.0   Diciembre  1,282          374         193             60
# ...

# %%
#Se observan los tipos de datos que hay ya que se deben de cambiar a numericos para poder hacer la regresion lineal
df1.dtypes
# Out:
# Año               float64
# Mes                   str
# Total              object
# Ilocalizable       object
# No Contesta        object
# D. Incorrectos     object
# Duplicados         object
# Efectivos          object
# Abiertos           object
# Ventas             object
# Conversion         object
# dtype: object

# %%
# Convertimos a texto, eliminamos espacios y unificamos la escritura
df1['Mes'] = df1['Mes'].astype(str).str.strip().str.capitalize()

# Revisamos cómo quedaron
df1['Mes'].unique()
# Out:
# <StringArray>
# [     'Enero',    'Febrero',      'Marzo',      'Abril',       'Mayo',
#       'Junio',      'Julio',     'Agosto', 'Septiembre',    'Octubre',
#   'Noviembre',  'Diciembre']
# Length: 12, dtype: str

# %%
#cambiamos el mes a tipo float, donde enero es 1, febrero es 2, marzo es 3, etc.
df1['Mes'] = df1['Mes'].map({'Enero': 1, 'Febrero': 2, 'Marzo': 3, 'Abril': 4, 'Mayo': 5, 'Junio': 6, 'Julio': 7, 'Agosto': 8, 'Septiembre': 9, 'Octubre': 10, 'Noviembre': 11, 'Diciembre': 12})

# %%
df1
# Out:
#        Año  Mes  Total Ilocalizable No Contesta D. Incorrectos Duplicados  \
# 0   2024.0    1      0            0           0              0          0
# 1   2024.0    2    543          108          33              0          1
# 2   2024.0    3    178           37          13              0          0
# 3   2024.0    4    416           79          46              3          0
# 4   2024.0    5    422           33         100             17          0
# 5   2024.0    6    967          140         173             31          3
# 6   2024.0    7    954          112         251             12          9
# 7   2024.0    8  1,409          504         324             17         18
# 8   2024.0    9  1,315          431         314             14         26
# 9   2024.0   10  1,973          514         606             18         13
# 10  2024.0   11  1,562          153         321             44          4
# 11  2024.0   12  1,282          374         193             60         53
# ...

# %%
#Quitar los procentajes de la columna Conversion
df1['Conversion '] = df1['Conversion '].str.rstrip('%').astype(float)

# %%
df1
# Out:
#        Año  Mes  Total Ilocalizable No Contesta D. Incorrectos Duplicados  \
# 0   2024.0    1      0            0           0              0          0
# 1   2024.0    2    543          108          33              0          1
# 2   2024.0    3    178           37          13              0          0
# 3   2024.0    4    416           79          46              3          0
# 4   2024.0    5    422           33         100             17          0
# 5   2024.0    6    967          140         173             31          3
# 6   2024.0    7    954          112         251             12          9
# 7   2024.0    8  1,409          504         324             17         18
# 8   2024.0    9  1,315          431         314             14         26
# 9   2024.0   10  1,973          514         606             18         13
# 10  2024.0   11  1,562          153         321             44          4
# 11  2024.0   12  1,282          374         193             60         53
# ...

# %%
#Quitar las comas en la columna Total, Ilocalizable, No Contesta, D. Incorrectos, Duplicados, Efectivos, Abiertos y Ventas
df1['Total'] = df1['Total'].str.replace(',', '').astype(float)

# %%
#Quitar las comas en la columna Total, Ilocalizable, No Contesta, D. Incorrectos, Duplicados, Efectivos, Abiertos y Ventas
df1['Efectivos'] = df1['Efectivos'].str.replace(',', '').astype(float)

# %%
#Pasar todas las columnas a tipo numerico
df1 = df1.apply(pd.to_numeric, errors='coerce')

# %%
df1.dtypes
# Out:
# Año               float64
# Mes                 int64
# Total             float64
# Ilocalizable        int64
# No Contesta         int64
# D. Incorrectos      int64
# Duplicados          int64
# Efectivos         float64
# Abiertos            int64
# Ventas              int64
# Conversion        float64
# dtype: object

# %%
df1
# Out:
#        Año  Mes   Total  Ilocalizable  No Contesta  D. Incorrectos  \
# 0   2024.0    1     NaN             0            0               0
# 1   2024.0    2   543.0           108           33               0
# 2   2024.0    3   178.0            37           13               0
# 3   2024.0    4   416.0            79           46               3
# 4   2024.0    5   422.0            33          100              17
# 5   2024.0    6   967.0           140          173              31
# 6   2024.0    7   954.0           112          251              12
# 7   2024.0    8  1409.0           504          324              17
# 8   2024.0    9  1315.0           431          314              14
# 9   2024.0   10  1973.0           514          606              18
# 10  2024.0   11  1562.0           153          321              44
# 11  2024.0   12  1282.0           374          193              60
# 12  2025.0    1  1042.0            17          104              62
# ...

# %%
#Quitar los NaN de las columnas
df1.fillna(0, inplace=True)
# Out:
#        Año  Mes   Total  Ilocalizable  No Contesta  D. Incorrectos  \
# 0   2024.0    1     0.0             0            0               0
# 1   2024.0    2   543.0           108           33               0
# 2   2024.0    3   178.0            37           13               0
# 3   2024.0    4   416.0            79           46               3
# 4   2024.0    5   422.0            33          100              17
# 5   2024.0    6   967.0           140          173              31
# 6   2024.0    7   954.0           112          251              12
# 7   2024.0    8  1409.0           504          324              17
# 8   2024.0    9  1315.0           431          314              14
# 9   2024.0   10  1973.0           514          606              18
# 10  2024.0   11  1562.0           153          321              44
# 11  2024.0   12  1282.0           374          193              60
# 12  2025.0    1  1042.0            17          104              62
# ...

# %%
#Corroboramos que se hayan quitado los NaN
df1
# Out:
#        Año  Mes   Total  Ilocalizable  No Contesta  D. Incorrectos  \
# 0   2024.0    1     0.0             0            0               0
# 1   2024.0    2   543.0           108           33               0
# 2   2024.0    3   178.0            37           13               0
# 3   2024.0    4   416.0            79           46               3
# 4   2024.0    5   422.0            33          100              17
# 5   2024.0    6   967.0           140          173              31
# 6   2024.0    7   954.0           112          251              12
# 7   2024.0    8  1409.0           504          324              17
# 8   2024.0    9  1315.0           431          314              14
# 9   2024.0   10  1973.0           514          606              18
# 10  2024.0   11  1562.0           153          321              44
# 11  2024.0   12  1282.0           374          193              60
# 12  2025.0    1  1042.0            17          104              62
# ...

# %% [markdown]
# Regresión lineal

# %%
#Imprimimos el scatter plot entre la variable dependiente e independiente
#para observar el comportamiento en su dispersión 
from turtle import color
sns.scatterplot(x='Ventas', y='Total', color="pink", data=df1)
# Out:
# <Axes: xlabel='Ventas', ylabel='Total'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df1[['Ventas']]
Var_Dep= df1['Total']

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Se define model como la función de regresión lineal
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'tol': 1e-06,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['Ventas'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([24.06909481]),
#  'rank_': np.int64(1),
#  'singular_': array([63.39531148]),
#  'intercept_': np.float64(457.5114972114974)}

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.3864845579529278

# %%
#Predecimos los valores de total de accidentes a partir de la variable "Ventas"
y_pred= model.predict(X=df1[['Ventas']])
y_pred
# Out:
# array([ 457.51149721,  746.34063492,  625.99516088,  650.06425568,
#         770.40972973,  601.92606607,  962.9624882 ,  866.68610897,
#         866.68610897, 1011.10067782,  987.03158301, 1227.7225311 ,
#        1083.30796225,  938.89339339, 1179.58434148, 1179.58434148,
#        1275.86072072, 1420.27528958, 1323.99891034, 1107.37705706,
#        1372.13709996, 1420.27528958, 1444.34438438, 1275.86072072,
#        1348.06800515, 1179.58434148, 1372.13709996, 1444.34438438,
#        1299.92981553])

# %%
#Insertamos la columna de predicciones en el DataFrame
df1.insert(0, 'Predicciones', y_pred)
df1
# Out:
#     Predicciones     Año  Mes   Total  Ilocalizable  No Contesta  \
# 0     457.511497  2024.0    1     0.0             0            0
# 1     746.340635  2024.0    2   543.0           108           33
# 2     625.995161  2024.0    3   178.0            37           13
# 3     650.064256  2024.0    4   416.0            79           46
# 4     770.409730  2024.0    5   422.0            33          100
# 5     601.926066  2024.0    6   967.0           140          173
# 6     962.962488  2024.0    7   954.0           112          251
# 7     866.686109  2024.0    8  1409.0           504          324
# 8     866.686109  2024.0    9  1315.0           431          314
# 9    1011.100678  2024.0   10  1973.0           514          606
# 10    987.031583  2024.0   11  1562.0           153          321
# 11   1227.722531  2024.0   12  1282.0           374          193
# 12   1083.307962  2025.0    1  1042.0            17          104
# ...

# %%
#Visualizamos la gráfica comparativa entre el total real y el total predecido

sns.scatterplot(x='Ventas', y='Total', color="blue", data=df1)
sns.scatterplot(x='Ventas', y='Predicciones', color="red", data=df1)
sns.lineplot(x='Ventas', y='Predicciones', color="red", data=df1)
# Out:
# <Axes: xlabel='Ventas', ylabel='Total'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.3864845579529278

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# np.float64(0.6216788221846774)

# %%
#Graficamos todas las dispersiones entre todas las variables
sns.pairplot(df1)

# %%
#Encontramos todas las correlaciones entre las variables 
Corr_Factors=df1.corr()
Corr_Factors
# Out:
#                 Predicciones       Año       Mes     Total  Ilocalizable  \
# Predicciones        1.000000  0.746773  0.273725  0.621679     -0.018107
# Año                 0.746773  1.000000 -0.298181  0.390258     -0.220409
# Mes                 0.273725 -0.298181  1.000000  0.479697      0.422512
# Total               0.621679  0.390258  0.479697  1.000000      0.599487
# Ilocalizable       -0.018107 -0.220409  0.422512  0.599487      1.000000
# No Contesta         0.297785 -0.075146  0.665231  0.669922      0.468315
# D. Incorrectos      0.205243  0.210277  0.050075  0.480309      0.317660
# Duplicados          0.483363  0.396225 -0.076695  0.316184     -0.120466
# Efectivos           0.724746  0.427469  0.431038  0.853120      0.302049
# Abiertos            0.752456  0.808063  0.103614  0.551099     -0.009711
# Ventas              1.000000  0.746773  0.273725  0.621679     -0.018107
# Conversion          0.704297  0.550205  0.079185  0.137652     -0.246187
#
# ...

# %%
#Encontramos el valor absoluto de todas las correlaciones entre las variables 
Corr_Factors1= abs(Corr_Factors)
Corr_Factors1
# Out:
#                 Predicciones       Año       Mes     Total  Ilocalizable  \
# Predicciones        1.000000  0.746773  0.273725  0.621679      0.018107
# Año                 0.746773  1.000000  0.298181  0.390258      0.220409
# Mes                 0.273725  0.298181  1.000000  0.479697      0.422512
# Total               0.621679  0.390258  0.479697  1.000000      0.599487
# Ilocalizable        0.018107  0.220409  0.422512  0.599487      1.000000
# No Contesta         0.297785  0.075146  0.665231  0.669922      0.468315
# D. Incorrectos      0.205243  0.210277  0.050075  0.480309      0.317660
# Duplicados          0.483363  0.396225  0.076695  0.316184      0.120466
# Efectivos           0.724746  0.427469  0.431038  0.853120      0.302049
# Abiertos            0.752456  0.808063  0.103614  0.551099      0.009711
# Ventas              1.000000  0.746773  0.273725  0.621679      0.018107
# Conversion          0.704297  0.550205  0.079185  0.137652      0.246187
#
# ...

# %%
#Ajustamos el mapa de calor de los coeficientes de correlación 
Heat_Map= sns.heatmap(Corr_Factors1, cmap = 'Blues', annot=True, fmt=".2f")  
Heat_Map
# Out:
# <Axes: >
